# %%
# Working with numpy and pandas examples

import numpy as np
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

X = np.random.normal(loc=1, scale=10, size=(1000, 50))
m = np.mean(X, axis=0)
std = np.std(X, axis=0)
r = np.sum(Z, axis=1)
A = np.eye(3)
B = np.eye(3)
AB = np.vstack((A, B))
data['Pclass'].value_counts()

X = np.array([[1, 2], [3, 4], [5, 6]])
y = np.array([0, 1, 0])
clf = DecisionTreeClassifier()
clf.fit(X, y)
importances = clf.feature_importances_
np.isnan(X)

# %%
# HOW TO PRINT Decision Tree with iris:

import sklearn
# print sklearn.__version__
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.externals.six import StringIO
from IPython.display import Image
import pydot

iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)

dot_data = StringIO()

tree.export_graphviz(clf, out_file=dot_data,  
                         feature_names=iris.feature_names,  
                         class_names=iris.target_names,  
                         filled=True, rounded=True,  
                         special_characters=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
data = pd.read_csv('titanic.csv', index_col='PassengerId')
print data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Оставьте в выборке четыре признака:
# класс пассажира (Pclass), цену билета (Fare), возраст пассажира (Age) и его пол (Sex).
data1 = data[["Pclass","Fare","Age","Sex", "Survived"]]
print data1.head()
print len(data1)
# Out:
#              Pclass     Fare  Age     Sex  Survived
# PassengerId
# 1                 3   7.2500   22    male         0
# 2                 1  71.2833   38  female         1
# 3                 3   7.9250   26  female         1
# 4                 1  53.1000   35  female         1
# 5                 3   8.0500   35    male         0
# 891

# %%
# data1.loc[:,"Sex"] = [int(x == "male") for x in data1["Sex"]]
data1.loc[:,"Sex"] = data1["Sex"].apply(lambda x: int(x == "male"))
data1 = data1.dropna(axis = 0)
print data1.head()
print len(data1)
# Out:
#              Pclass     Fare  Age  Sex  Survived
# PassengerId
# 1                 3   7.2500   22    1         0
# 2                 1  71.2833   38    0         1
# 3                 3   7.9250   26    0         1
# 4                 1  53.1000   35    0         1
# 5                 3   8.0500   35    1         0
# 714

# %%
target = np.array(data1["Survived"])
print target[:10]
# Out:
# [0 1 1 1 0 0 0 1 1 1]

# %%
data1 = data1[["Pclass", "Fare", "Age", "Sex"]]
clf2 = DecisionTreeClassifier(random_state = 241)
clf2.fit(data1, target)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=241, splitter='best')

# %%
importances = clf2.feature_importances_
print importances
# Out:
# [ 0.14000522  0.30343647  0.2560461   0.30051221]

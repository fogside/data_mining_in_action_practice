# %% [markdown]
# # Lol
# * Сформируйте систему линейных уравнений (то есть задайте матрицу коэффициентов A и свободный вектор b) для многочлена первой степени, который должен совпадать с функцией f в точках 1 и 15.
#
# * Решите данную систему с помощью функции scipy.linalg.solve. Нарисуйте функцию f и полученный многочлен. Хорошо ли он приближает исходную функцию?
#
# * Повторите те же шаги для многочлена второй степени, который совпадает с функцией f в точках 1, 8 и 15. Улучшилось ли качество аппроксимации?
# * Повторите те же шаги для многочлена третьей степени, который совпадает с функцией f в точках 1, 4, 10 и 15. Хорошо ли он аппроксимирует функцию? Коэффициенты данного многочлена (четыре числа: w_0, w_1, w_2, w_3) являются ответом на задачу.
# * Запишите полученные числа в файл, разделив пробелами. Обратите внимание, что файл должен состоять из одной строки, в конце которой не должно быть переноса. Пример файла с решением вы можете найти в конце задания (submission-2.txt).

# %%
import numpy as np
import math as m
from scipy import linalg as lin
f = lambda x: m.sin(x / 5.) * m.exp(x / 10.) + 5 * m.exp(-x / 2.)
print f(1), f(15)
# Out:
# 3.25221686527 0.635221419579

# %%
A1 = np.array([[1,1],[15,1]]) #linear
A2 = np.array([[1,1,1],[64,8,1],[15*15,15,1]])
A3 = np.array([[1,1,1,1],[64,16,4,1],[1000,100,10,1],[15**3,15**2,15,1]])

# %%
# ?lin.solve()

# %%
f1 = np.array([f(1), f(15)])
f2 = np.array([f(1),f(8), f(15)])
f3 = np.array([f(1),f(4),f(10), f(15)])

# %%
lin.solve(A1, f1)
# Out:
# array([-0.18692825,  3.43914511])

# %%
# %matplotlib inline
from matplotlib import pylab as plt

F1 = lambda x: -0.18692825*x+3.43914511
x = np.arange(1,16,0.5)
real_val = [f(i) for i in x]

plt.plot(x, F1(x), x, real_val)
plt.show()
print x
# Out:
# [  1.    1.5   2.    2.5   3.    3.5   4.    4.5   5.    5.5   6.    6.5
#    7.    7.5   8.    8.5   9.    9.5  10.   10.5  11.   11.5  12.   12.5
#   13.   13.5  14.   14.5  15.   15.5]

# %%
lin.solve(A2, f2)
# Out:
# array([-0.00760104, -0.06531159,  3.32512949])

# %%
F2 = lambda x: -0.00760104*x**2+-0.06531159*x+3.32512949

plt.plot(x, F2(x), x, real_val)
plt.show()
print x
# Out:
# [  1.    1.5   2.    2.5   3.    3.5   4.    4.5   5.    5.5   6.    6.5
#    7.    7.5   8.    8.5   9.    9.5  10.   10.5  11.   11.5  12.   12.5
#   13.   13.5  14.   14.5  15.   15.5]

# %%
A = lin.solve(A3, f3)
A
# Out:
# array([-0.00823565,  0.19333685, -1.29552587,  4.36264154])

# %%
F2 = lambda x: -0.00823565*x**3+0.19333685*x**2-1.29552587*x+4.36264154

plt.plot(x, F2(x), x, real_val)
plt.show()
print x
# Out:
# [  1.    1.5   2.    2.5   3.    3.5   4.    4.5   5.    5.5   6.    6.5
#    7.    7.5   8.    8.5   9.    9.5  10.   10.5  11.   11.5  12.   12.5
#   13.   13.5  14.   14.5  15.   15.5]
